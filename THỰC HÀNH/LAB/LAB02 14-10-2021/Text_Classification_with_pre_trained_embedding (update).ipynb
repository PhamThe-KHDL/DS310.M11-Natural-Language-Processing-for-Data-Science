# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path = '/content/drive/MyDrive/Dataset/UIT-VSFC'
X_train = pd.read_csv(path + '/train/sents.txt',  sep='\n', header=None, index_col=None)
X_train = X_train.iloc[:, 0]
y_train = pd.read_csv(path + '/train/sentiments.txt',  sep='\n', header=None, index_col=None)
y_train_topic = pd.read_csv(path + '/train/topics.txt',  sep='\n', header=None, index_col=None)

X_dev = pd.read_csv(path + '/dev/sents.txt', sep='\n', header=None, index_col=None)
X_dev = X_dev.iloc[:, 0]
y_dev = pd.read_csv(path + '/dev/sentiments.txt', sep='\n', header=None, index_col=None)
y_dev_topic = pd.read_csv(path + '/dev/topics.txt',  sep='\n', header=None, index_col=None)


X_test = pd.read_csv(path + '/test/sents.txt',  sep='\n', header=None, index_col=None)
X_test = X_test.iloc[:, 0]
y_test = pd.read_csv(path + '/test/sentiments.txt',  sep='\n', header=None, index_col=None)
y_test_topic = pd.read_csv(path + '/test/topics.txt',  sep='\n', header=None, index_col=None)


y_train = y_train.values.flatten()
y_dev = y_dev.values.flatten()
y_test = y_test.values.flatten()

# %%
X_train.head(10)
# Out:
# 0                            slide giáo trình đầy đủ .
# 1       nhiệt tình giảng dạy , gần gũi với sinh viên .
# 2                 đi học đầy đủ full điểm chuyên cần .
# 3    chưa áp dụng công nghệ thông tin và các thiết ...
# 4    thầy giảng bài hay , có nhiều bài tập ví dụ ng...
# 5    giảng viên đảm bảo thời gian lên lớp , tích cự...
# 6    em sẽ nợ môn này , nhưng em sẽ học lại ở các h...
# 7    thời lượng học quá dài , không đảm bảo tiếp th...
# 8    nội dung môn học có phần thiếu trọng tâm , hầu...
# 9    cần nói rõ hơn bằng cách trình bày lên bảng th...
# Name: 0, dtype: object

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf_idf = TfidfVectorizer(analyzer='word', ngram_range=(2,2))
tf_idf.fit(X_train)

X_train_encoded = tf_idf.transform(X_train)
X_dev_encoded = tf_idf.transform(X_dev)
X_test_encoded = tf_idf.transform(X_test)

# %%
X_train_encoded.shape
# Out:
# (11426, 31384)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_encoded, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred_dev = model.predict(X_dev_encoded)
y_pred_test = model.predict(X_test_encoded)

# %%
from sklearn.metrics import f1_score

print(f1_score(y_dev, y_pred_dev, average='micro')*100)
print(f1_score(y_test, y_pred_test, average='micro')*100)
# Out:
# 87.17624763108023
# 86.35502210991788

# %% [markdown]
# # Gensim - Build simple word embedding

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)

# %%
pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 4.6 MB/s
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.7-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 20.4 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.62.3)
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.7 pyvi-0.1.1 sklearn-crfsuite-0.3.6

# %%
from pyvi import ViTokenizer

sentences = X_train.values

tokenized_sentences = []

for s in sentences:
    tokenized_sentences.append(ViTokenizer.tokenize(s).split())

# %%
import multiprocessing
from gensim.models import Word2Vec

w2v_model = Word2Vec(min_count=20, window=2, size=300)
w2v_model.build_vocab(tokenized_sentences)

# %%
w2v_model.train(tokenized_sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
# Out:
# (2134262, 3851460)

# %%
w2v_model.wv.vocab
# Out:
# {'!': <gensim.models.keyedvectors.Vocab at 0x7facd9e70410>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x7facd9e819d0>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c6d0>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c790>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c7d0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7facd9e65810>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7facd9e77ad0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7facd9ebde10>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7facd9e81190>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ae50>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7facd9e816d0>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7facd9e77a90>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7facd9e84f50>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a2d0>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7facd9e81f10>,
#  'ai': <gensim.models.keyedvectors.Vocab at 0x7facd9e7aa10>,
#  'anh': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ce90>,
#  'biết': <gensim.models.keyedvectors.Vocab at 0x7facd9e74710>,
#  'buồn_ngủ': <gensim.models.keyedvectors.Vocab at 0x7facd9e771d0>,
#  'buổi': <gensim.models.keyedvectors.Vocab at 0x7facd9e70510>,
#  'bài': <gensim.models.keyedvectors.Vocab at 0x7facd9e65d50>,
#  'bài_học': <gensim.models.keyedvectors.Vocab at 0x7facd9e81d50>,
#  'bài_tập': <gensim.models.keyedvectors.Vocab at 0x7facd9e65e50>,
#  'bám': <gensim.models.keyedvectors.Vocab at 0x7facd9e81390>,
#  'báo': <gensim.models.keyedvectors.Vocab at 0x7facd9e882d0>,
#  'báo_cáo': <gensim.models.keyedvectors.Vocab at 0x7facd9e84210>,
#  'bên': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c850>,
#  'bù': <gensim.models.keyedvectors.Vocab at 0x7facd9e77650>,
#  'bạn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c650>,
#  'bảng': <gensim.models.keyedvectors.Vocab at 0x7facd9e6eb10>,
#  'bận': <gensim.models.keyedvectors.Vocab at 0x7facd9e81b50>,
#  'bắt': <gensim.models.keyedvectors.Vocab at 0x7facd9e88450>,
#  'bắt_đầu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7afd0>,
#  'bằng': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ea10>,
#  'bị': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ed50>,
#  'bọn': <gensim.models.keyedvectors.Vocab at 0x7facd9e81f50>,
#  'bỏ': <gensim.models.keyedvectors.Vocab at 0x7facd9e74d50>,
#  'bổ_sung': <gensim.models.keyedvectors.Vocab at 0x7facd9e70910>,
#  'bổ_ích': <gensim.models.keyedvectors.Vocab at 0x7facd9e84610>,
#  'bộ_môn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c950>,
#  'bớt': <gensim.models.keyedvectors.Vocab at 0x7facd9e81d10>,
#  'cao': <gensim.models.keyedvectors.Vocab at 0x7facd9e74850>,
#  'chi_tiết': <gensim.models.keyedvectors.Vocab at 0x7facd9e707d0>,
#  'chia': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c310>,
#  'chia_sẻ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c090>,
#  'cho': <gensim.models.keyedvectors.Vocab at 0x7facd9e65c50>,
#  'chu_đáo': <gensim.models.keyedvectors.Vocab at 0x7facd9e81e50>,
#  'chung': <gensim.models.keyedvectors.Vocab at 0x7facd9e81790>,
#  'chuyên_môn': <gensim.models.keyedvectors.Vocab at 0x7facd9e84e10>,
#  'chuyên_ngành': <gensim.models.keyedvectors.Vocab at 0x7facd9e70650>,
#  'chuyên_sâu': <gensim.models.keyedvectors.Vocab at 0x7facd9e88310>,
#  'chuyện': <gensim.models.keyedvectors.Vocab at 0x7facd9e81050>,
#  'chuẩn': <gensim.models.keyedvectors.Vocab at 0x7facd9e88290>,
#  'chuẩn_bị': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c390>,
#  'chán': <gensim.models.keyedvectors.Vocab at 0x7facd9e70c50>,
#  'chép': <gensim.models.keyedvectors.Vocab at 0x7facd9e740d0>,
#  'chính': <gensim.models.keyedvectors.Vocab at 0x7facd9e813d0>,
#  'chính_xác': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c290>,
#  'chú_trọng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81810>,
#  'chú_ý': <gensim.models.keyedvectors.Vocab at 0x7facd9e840d0>,
#  'chúng': <gensim.models.keyedvectors.Vocab at 0x7facd9e74990>,
#  'chút': <gensim.models.keyedvectors.Vocab at 0x7facd9e815d0>,
#  'chưa': <gensim.models.keyedvectors.Vocab at 0x7facd9e65a50>,
#  'chương_trình': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ad10>,
#  'chạy': <gensim.models.keyedvectors.Vocab at 0x7facd9e88690>,
#  'chấm': <gensim.models.keyedvectors.Vocab at 0x7facd9e74d90>,
#  'chất_lượng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81d90>,
#  'chậm': <gensim.models.keyedvectors.Vocab at 0x7facd9e81bd0>,
#  'chắc': <gensim.models.keyedvectors.Vocab at 0x7facd9e88790>,
#  'chỉ': <gensim.models.keyedvectors.Vocab at 0x7facd9e74bd0>,
#  'chỉ_bảo': <gensim.models.keyedvectors.Vocab at 0x7facd9e84810>,
#  'chỉ_dẫn': <gensim.models.keyedvectors.Vocab at 0x7facd9e88390>,
#  'chỗ': <gensim.models.keyedvectors.Vocab at 0x7facd9e81c50>,
#  'chủ_yếu': <gensim.models.keyedvectors.Vocab at 0x7facd9e84510>,
#  'chủ_động': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ac50>,
#  'chứ': <gensim.models.keyedvectors.Vocab at 0x7facd9e84090>,
#  'chữ': <gensim.models.keyedvectors.Vocab at 0x7facd9e84710>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x7facd9e74e90>,
#  'colonsmile': <gensim.models.keyedvectors.Vocab at 0x7facd9e84350>,
#  'cung_cấp': <gensim.models.keyedvectors.Vocab at 0x7facd9e743d0>,
#  'cuối': <gensim.models.keyedvectors.Vocab at 0x7facd9e77410>,
#  'cuối_cùng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84250>,
#  'các': <gensim.models.keyedvectors.Vocab at 0x7facd9e65b90>,
#  'cách': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ea50>,
#  'cái': <gensim.models.keyedvectors.Vocab at 0x7facd9e74750>,
#  'câu': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e150>,
#  'còn': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ee90>,
#  'có': <gensim.models.keyedvectors.Vocab at 0x7facd9e65dd0>,
#  'có_thể': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ef50>,
#  'cô': <gensim.models.keyedvectors.Vocab at 0x7facd9e74190>,
#  'cô_giáo': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cd10>,
#  'công_bằng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81250>,
#  'công_nghệ': <gensim.models.keyedvectors.Vocab at 0x7facd9e65ad0>,
#  'công_tác': <gensim.models.keyedvectors.Vocab at 0x7facd9e883d0>,
#  'công_việc': <gensim.models.keyedvectors.Vocab at 0x7facd9e84310>,
#  'cùng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a9d0>,
#  'cũ': <gensim.models.keyedvectors.Vocab at 0x7facd9e84a10>,
#  'cũng': <gensim.models.keyedvectors.Vocab at 0x7facd9e77790>,
#  'cơ_bản': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c750>,
#  'cơ_hội': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a8d0>,
#  'cơ_sở': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a110>,
#  'cả': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c690>,
#  'cải_thiện': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a0d0>,
#  'cảm_giác': <gensim.models.keyedvectors.Vocab at 0x7facd9e70c10>,
#  'cảm_hứng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81b90>,
#  'cảm_thấy': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a490>,
#  'cảm_ơn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cf90>,
#  'cần': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e910>,
#  'cần_thiết': <gensim.models.keyedvectors.Vocab at 0x7facd9e749d0>,
#  'cập_nhật': <gensim.models.keyedvectors.Vocab at 0x7facd9e77d10>,
#  'cố_gắng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c8d0>,
#  'cộng': <gensim.models.keyedvectors.Vocab at 0x7facd9e884d0>,
#  'cụ_thể': <gensim.models.keyedvectors.Vocab at 0x7facd9e70a10>,
#  'của': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e1d0>,
#  'củng_cố': <gensim.models.keyedvectors.Vocab at 0x7facd9e84b90>,
#  'cứ': <gensim.models.keyedvectors.Vocab at 0x7facd9e81c10>,
#  'cực_kỳ': <gensim.models.keyedvectors.Vocab at 0x7facd9e842d0>,
#  'deadline': <gensim.models.keyedvectors.Vocab at 0x7facd9e77750>,
#  'demo': <gensim.models.keyedvectors.Vocab at 0x7facd9e84f90>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7facd9e81950>,
#  'doubledot': <gensim.models.keyedvectors.Vocab at 0x7facd9e74a10>,
#  'dài': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e510>,
#  'dành': <gensim.models.keyedvectors.Vocab at 0x7facd9e88090>,
#  'dù': <gensim.models.keyedvectors.Vocab at 0x7facd9e748d0>,
#  'dùng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84990>,
#  'dưới': <gensim.models.keyedvectors.Vocab at 0x7facd9e88210>,
#  'dạng': <gensim.models.keyedvectors.Vocab at 0x7facd9e77990>,
#  'dạy': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ec50>,
#  'dạy_học': <gensim.models.keyedvectors.Vocab at 0x7facd9e814d0>,
#  'dẫn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cb50>,
#  'dễ': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ed10>,
#  'dễ_chịu': <gensim.models.keyedvectors.Vocab at 0x7facd9e74b50>,
#  'dễ_dàng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cdd0>,
#  'dễ_thương': <gensim.models.keyedvectors.Vocab at 0x7facd9e7add0>,
#  'dễ_tính': <gensim.models.keyedvectors.Vocab at 0x7facd9e88250>,
#  'em': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e290>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7facd9e886d0>,
#  'giao': <gensim.models.keyedvectors.Vocab at 0x7facd9e88050>,
#  'giao_tiếp': <gensim.models.keyedvectors.Vocab at 0x7facd9e81310>,
#  'giáo_trình': <gensim.models.keyedvectors.Vocab at 0x7facd9ecd610>,
#  'giáo_viên': <gensim.models.keyedvectors.Vocab at 0x7facd9e77550>,
#  'giúp': <gensim.models.keyedvectors.Vocab at 0x7facd9e70090>,
#  'giúp_đỡ': <gensim.models.keyedvectors.Vocab at 0x7facd9e70350>,
#  'giải': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a6d0>,
#  'giải_quyết': <gensim.models.keyedvectors.Vocab at 0x7facd9e74110>,
#  'giải_thích': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a1d0>,
#  'giải_đáp': <gensim.models.keyedvectors.Vocab at 0x7facd9e7aa90>,
#  'giảm': <gensim.models.keyedvectors.Vocab at 0x7facd9e77250>,
#  'giảng': <gensim.models.keyedvectors.Vocab at 0x7facd9e65d10>,
#  'giảng_dạy': <gensim.models.keyedvectors.Vocab at 0x7facd9e65850>,
#  'giảng_giải': <gensim.models.keyedvectors.Vocab at 0x7facd9e77d90>,
#  'giảng_viên': <gensim.models.keyedvectors.Vocab at 0x7facd9e65f90>,
#  'giọng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81550>,
#  'giỏi': <gensim.models.keyedvectors.Vocab at 0x7facd9e81e10>,
#  'giống': <gensim.models.keyedvectors.Vocab at 0x7facd9e74650>,
#  'giới_thiệu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a910>,
#  'giờ': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ecd0>,
#  'giờ_giấc': <gensim.models.keyedvectors.Vocab at 0x7facd9e84590>,
#  'giữa': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a610>,
#  'gây': <gensim.models.keyedvectors.Vocab at 0x7facd9e74310>,
#  'gì': <gensim.models.keyedvectors.Vocab at 0x7facd9e74790>,
#  'gần': <gensim.models.keyedvectors.Vocab at 0x7facd9e77150>,
#  'gần_gũi': <gensim.models.keyedvectors.Vocab at 0x7facd9e65910>,
#  'gặp': <gensim.models.keyedvectors.Vocab at 0x7facd9e74510>,
#  'gửi': <gensim.models.keyedvectors.Vocab at 0x7facd9e81ed0>,
#  'hai': <gensim.models.keyedvectors.Vocab at 0x7facd9e74b10>,
#  'hay': <gensim.models.keyedvectors.Vocab at 0x7facd9e65d90>,
#  'hiền': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cd50>,
#  'hiểu': <gensim.models.keyedvectors.Vocab at 0x7facd9e700d0>,
#  'hiện_tại': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a090>,
#  'hiệu_quả': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e5d0>,
#  'hoàn_thành': <gensim.models.keyedvectors.Vocab at 0x7facd9e81750>,
#  'hoàn_toàn': <gensim.models.keyedvectors.Vocab at 0x7facd9e88550>,
#  'hoạt_động': <gensim.models.keyedvectors.Vocab at 0x7facd9e70490>,
#  'hoặc': <gensim.models.keyedvectors.Vocab at 0x7facd9e77950>,
#  'hy_vọng': <gensim.models.keyedvectors.Vocab at 0x7facd9e74590>,
#  'hài_hước': <gensim.models.keyedvectors.Vocab at 0x7facd9e81f90>,
#  'hài_lòng': <gensim.models.keyedvectors.Vocab at 0x7facd9e70190>,
#  'hình_thức': <gensim.models.keyedvectors.Vocab at 0x7facd9e74610>,
#  'hòa': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ca50>,
#  'hôm': <gensim.models.keyedvectors.Vocab at 0x7facd9e84690>,
#  'hơi': <gensim.models.keyedvectors.Vocab at 0x7facd9e779d0>,
#  'hơn': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e9d0>,
#  'hướng': <gensim.models.keyedvectors.Vocab at 0x7facd9e744d0>,
#  'hướng_dẫn': <gensim.models.keyedvectors.Vocab at 0x7facd9e70790>,
#  'hạn_chế': <gensim.models.keyedvectors.Vocab at 0x7facd9e84750>,
#  'hấp_dẫn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ac10>,
#  'hầu_như': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e750>,
#  'hết': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a550>,
#  'hệ_thống': <gensim.models.keyedvectors.Vocab at 0x7facd9e74f10>,
#  'học': <gensim.models.keyedvectors.Vocab at 0x7facd9e659d0>,
#  'học_kỳ': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e450>,
#  'học_sinh': <gensim.models.keyedvectors.Vocab at 0x7facd9e77190>,
#  'học_tập': <gensim.models.keyedvectors.Vocab at 0x7facd9e70390>,
#  'hỏi': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e190>,
#  'hỗ_trợ': <gensim.models.keyedvectors.Vocab at 0x7facd9e65c10>,
#  'hợp_lý': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a7d0>,
#  'hứng_thú': <gensim.models.keyedvectors.Vocab at 0x7facd9e77350>,
#  'hữu_ích': <gensim.models.keyedvectors.Vocab at 0x7facd9e84dd0>,
#  'khi': <gensim.models.keyedvectors.Vocab at 0x7facd9e74210>,
#  'khiến': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e7d0>,
#  'khoa': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c190>,
#  'khoảng': <gensim.models.keyedvectors.Vocab at 0x7facd9e88910>,
#  'khá': <gensim.models.keyedvectors.Vocab at 0x7facd9e74390>,
#  'khác': <gensim.models.keyedvectors.Vocab at 0x7facd9e774d0>,
#  'khó': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e850>,
#  'khó_khăn': <gensim.models.keyedvectors.Vocab at 0x7facd9e74350>,
#  'khóa': <gensim.models.keyedvectors.Vocab at 0x7facd9e81150>,
#  'khô_khan': <gensim.models.keyedvectors.Vocab at 0x7facd9e70fd0>,
#  'không': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e550>,
#  'không_khí': <gensim.models.keyedvectors.Vocab at 0x7facd9e81690>,
#  'không_thể': <gensim.models.keyedvectors.Vocab at 0x7facd9e74fd0>,
#  'khả_năng': <gensim.models.keyedvectors.Vocab at 0x7facd9e77e10>,
#  'kinh_nghiệm': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a050>,
#  'kiến_thức': <gensim.models.keyedvectors.Vocab at 0x7facd9e74090>,
#  'kiểm_tra': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c590>,
#  'kiểu': <gensim.models.keyedvectors.Vocab at 0x7facd9e77310>,
#  'kém': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a790>,
#  'kết_hợp': <gensim.models.keyedvectors.Vocab at 0x7facd9e70450>,
#  'kết_quả': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cb90>,
#  'kết_thúc': <gensim.models.keyedvectors.Vocab at 0x7facd9e88750>,
#  'kể': <gensim.models.keyedvectors.Vocab at 0x7facd9e84650>,
#  'kịp': <gensim.models.keyedvectors.Vocab at 0x7facd9e847d0>,
#  'kỳ': <gensim.models.keyedvectors.Vocab at 0x7facd9e77450>,
#  'kỹ': <gensim.models.keyedvectors.Vocab at 0x7facd9e70ad0>,
#  'kỹ_càng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84a90>,
#  'kỹ_năng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ad50>,
#  'lab': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c150>,
#  'lan_man': <gensim.models.keyedvectors.Vocab at 0x7facd9e81ad0>,
#  'liên_hệ': <gensim.models.keyedvectors.Vocab at 0x7facd9e81490>,
#  'liên_quan': <gensim.models.keyedvectors.Vocab at 0x7facd9e74410>,
#  'liên_tục': <gensim.models.keyedvectors.Vocab at 0x7facd9e775d0>,
#  'luôn': <gensim.models.keyedvectors.Vocab at 0x7facd9e74950>,
#  'là': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e790>,
#  'làm': <gensim.models.keyedvectors.Vocab at 0x7facd9e70890>,
#  'làm_việc': <gensim.models.keyedvectors.Vocab at 0x7facd9e6efd0>,
#  'lâu': <gensim.models.keyedvectors.Vocab at 0x7facd9e88490>,
#  'lên': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ead0>,
#  'lên_lớp': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e090>,
#  'lôi_cuốn': <gensim.models.keyedvectors.Vocab at 0x7facd9e84450>,
#  'lúc': <gensim.models.keyedvectors.Vocab at 0x7facd9e70850>,
#  'lý_thuyết': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a850>,
#  'lượng': <gensim.models.keyedvectors.Vocab at 0x7facd9e74050>,
#  'lại': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e3d0>,
#  'lấy': <gensim.models.keyedvectors.Vocab at 0x7facd9e70b10>,
#  'lần': <gensim.models.keyedvectors.Vocab at 0x7facd9e70bd0>,
#  'lập_trình': <gensim.models.keyedvectors.Vocab at 0x7facd9e77cd0>,
#  'lắm': <gensim.models.keyedvectors.Vocab at 0x7facd9e770d0>,
#  'lắng_nghe': <gensim.models.keyedvectors.Vocab at 0x7facd9e88950>,
#  'lịch': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c450>,
#  'lỗi': <gensim.models.keyedvectors.Vocab at 0x7facd9e843d0>,
#  'lớn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a390>,
#  'lớp': <gensim.models.keyedvectors.Vocab at 0x7facd9e65f50>,
#  'lớp_học': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a210>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x7facd9e84d50>,
#  'mang': <gensim.models.keyedvectors.Vocab at 0x7facd9e84890>,
#  'micro': <gensim.models.keyedvectors.Vocab at 0x7facd9e81590>,
#  'minh_họa': <gensim.models.keyedvectors.Vocab at 0x7facd9e70b50>,
#  'mong': <gensim.models.keyedvectors.Vocab at 0x7facd9e77210>,
#  'moodle': <gensim.models.keyedvectors.Vocab at 0x7facd9e70950>,
#  'muốn': <gensim.models.keyedvectors.Vocab at 0x7facd9e81210>,
#  'muộn': <gensim.models.keyedvectors.Vocab at 0x7facd9e88190>,
#  'mà': <gensim.models.keyedvectors.Vocab at 0x7facd9e746d0>,
#  'máy': <gensim.models.keyedvectors.Vocab at 0x7facd9e778d0>,
#  'máy_chiếu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a190>,
#  'máy_tính': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c9d0>,
#  'mình': <gensim.models.keyedvectors.Vocab at 0x7facd9e70150>,
#  'môn': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e310>,
#  'môn_học': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e650>,
#  'mơ_hồ': <gensim.models.keyedvectors.Vocab at 0x7facd9e84390>,
#  'mạng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c1d0>,
#  'mất': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a250>,
#  'mấy': <gensim.models.keyedvectors.Vocab at 0x7facd9e77490>,
#  'mẫu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c610>,
#  'mặc_dù': <gensim.models.keyedvectors.Vocab at 0x7facd9e741d0>,
#  'mặt': <gensim.models.keyedvectors.Vocab at 0x7facd9e84910>,
#  'mọi': <gensim.models.keyedvectors.Vocab at 0x7facd9e81510>,
#  'mỗi': <gensim.models.keyedvectors.Vocab at 0x7facd9e70f50>,
#  'một': <gensim.models.keyedvectors.Vocab at 0x7facd9e70c90>,
#  'một_chút': <gensim.models.keyedvectors.Vocab at 0x7facd9e88610>,
#  'một_cách': <gensim.models.keyedvectors.Vocab at 0x7facd9e74dd0>,
#  'một_số': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c3d0>,
#  'mới': <gensim.models.keyedvectors.Vocab at 0x7facd9e77d50>,
#  'mờ': <gensim.models.keyedvectors.Vocab at 0x7facd9e880d0>,
#  'mở': <gensim.models.keyedvectors.Vocab at 0x7facd9e881d0>,
#  'mở_rộng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81290>,
#  'mục_tiêu': <gensim.models.keyedvectors.Vocab at 0x7facd9e81c90>,
#  'mục_đích': <gensim.models.keyedvectors.Vocab at 0x7facd9e7af90>,
#  'mức_độ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cc90>,
#  'ngay': <gensim.models.keyedvectors.Vocab at 0x7facd9e65ed0>,
#  'nghe': <gensim.models.keyedvectors.Vocab at 0x7facd9e77ed0>,
#  'nghiêm_túc': <gensim.models.keyedvectors.Vocab at 0x7facd9e81650>,
#  'nghiên_cứu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c410>,
#  'nghĩ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c990>,
#  'nghỉ': <gensim.models.keyedvectors.Vocab at 0x7facd9e77590>,
#  'ngoài': <gensim.models.keyedvectors.Vocab at 0x7facd9e77090>,
#  'ngoài_ra': <gensim.models.keyedvectors.Vocab at 0x7facd9e81fd0>,
#  'ngành': <gensim.models.keyedvectors.Vocab at 0x7facd9e70110>,
#  'ngày': <gensim.models.keyedvectors.Vocab at 0x7facd9e845d0>,
#  'ngôn_ngữ': <gensim.models.keyedvectors.Vocab at 0x7facd9e88710>,
#  'người': <gensim.models.keyedvectors.Vocab at 0x7facd9e7aa50>,
#  'ngắn': <gensim.models.keyedvectors.Vocab at 0x7facd9e84490>,
#  'ngắn_gọn': <gensim.models.keyedvectors.Vocab at 0x7facd9e81dd0>,
#  'ngồi': <gensim.models.keyedvectors.Vocab at 0x7facd9e77890>,
#  'ngữ_pháp': <gensim.models.keyedvectors.Vocab at 0x7facd9e81850>,
#  'nhanh': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a750>,
#  'nhau': <gensim.models.keyedvectors.Vocab at 0x7facd9e77510>,
#  'nhiều': <gensim.models.keyedvectors.Vocab at 0x7facd9e65e10>,
#  'nhiệt_huyết': <gensim.models.keyedvectors.Vocab at 0x7facd9e74890>,
#  'nhiệt_tình': <gensim.models.keyedvectors.Vocab at 0x7facd9e658d0>,
#  'nhà': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a290>,
#  'nhà_trường': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ae10>,
#  'nhàm_chán': <gensim.models.keyedvectors.Vocab at 0x7facd9e70f90>,
#  'nhìn': <gensim.models.keyedvectors.Vocab at 0x7facd9e6eb90>,
#  'nhóm': <gensim.models.keyedvectors.Vocab at 0x7facd9e77f50>,
#  'như': <gensim.models.keyedvectors.Vocab at 0x7facd9e74690>,
#  'như_vậy': <gensim.models.keyedvectors.Vocab at 0x7facd9e77a10>,
#  'nhưng': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e390>,
#  'nhất': <gensim.models.keyedvectors.Vocab at 0x7facd9e7af50>,
#  'nhận': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ced0>,
#  'nhỏ': <gensim.models.keyedvectors.Vocab at 0x7facd9e77e50>,
#  'nhớ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ab90>,
#  'những': <gensim.models.keyedvectors.Vocab at 0x7facd9e70a50>,
#  'nào': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a4d0>,
#  'này': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e350>,
#  'nâng': <gensim.models.keyedvectors.Vocab at 0x7facd9e6eed0>,
#  'nâng_cấp': <gensim.models.keyedvectors.Vocab at 0x7facd9e74ed0>,
#  'nên': <gensim.models.keyedvectors.Vocab at 0x7facd9e709d0>,
#  'nêu': <gensim.models.keyedvectors.Vocab at 0x7facd9e84410>,
#  'nó': <gensim.models.keyedvectors.Vocab at 0x7facd9e74c50>,
#  'nói': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e950>,
#  'nói_chung': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ccd0>,
#  'nói_chuyện': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c050>,
#  'nóng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84b50>,
#  'năm': <gensim.models.keyedvectors.Vocab at 0x7facd9e811d0>,
#  'nắm': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e890>,
#  'nắm_bắt': <gensim.models.keyedvectors.Vocab at 0x7facd9e77fd0>,
#  'nặng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84e90>,
#  'nếu': <gensim.models.keyedvectors.Vocab at 0x7facd9e77e90>,
#  'nội_dung': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e610>,
#  'nộp': <gensim.models.keyedvectors.Vocab at 0x7facd9e74a50>,
#  'nữa': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ef10>,
#  'phong_cách': <gensim.models.keyedvectors.Vocab at 0x7facd9e703d0>,
#  'phong_phú': <gensim.models.keyedvectors.Vocab at 0x7facd9e81990>,
#  'phát_triển': <gensim.models.keyedvectors.Vocab at 0x7facd9e88850>,
#  'phát_âm': <gensim.models.keyedvectors.Vocab at 0x7facd9e84f10>,
#  'phòng': <gensim.models.keyedvectors.Vocab at 0x7facd9e74f90>,
#  'phù_hợp': <gensim.models.keyedvectors.Vocab at 0x7facd9e77290>,
#  'phút': <gensim.models.keyedvectors.Vocab at 0x7facd9e77b10>,
#  'phương_pháp': <gensim.models.keyedvectors.Vocab at 0x7facd9e77f90>,
#  'phải': <gensim.models.keyedvectors.Vocab at 0x7facd9e70990>,
#  'phần': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e690>,
#  'phần_mềm': <gensim.models.keyedvectors.Vocab at 0x7facd9e84110>,
#  'qua': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ee10>,
#  'quan_trọng': <gensim.models.keyedvectors.Vocab at 0x7facd9e70a90>,
#  'quan_tâm': <gensim.models.keyedvectors.Vocab at 0x7facd9e70710>,
#  'quá': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e4d0>,
#  'quá_trình': <gensim.models.keyedvectors.Vocab at 0x7facd9e84550>,
#  'quạt': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c510>,
#  'quản_lý': <gensim.models.keyedvectors.Vocab at 0x7facd9e88110>,
#  'ra': <gensim.models.keyedvectors.Vocab at 0x7facd9e74490>,
#  'riêng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81090>,
#  'rèn_luyện': <gensim.models.keyedvectors.Vocab at 0x7facd9e848d0>,
#  'rõ': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e990>,
#  'rõ_ràng': <gensim.models.keyedvectors.Vocab at 0x7facd9e74e10>,
#  'rất': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e810>,
#  'rồi': <gensim.models.keyedvectors.Vocab at 0x7facd9e77850>,
#  'rộng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81890>,
#  'sai': <gensim.models.keyedvectors.Vocab at 0x7facd9e77b90>,
#  'sao': <gensim.models.keyedvectors.Vocab at 0x7facd9e888d0>,
#  'sau': <gensim.models.keyedvectors.Vocab at 0x7facd9e745d0>,
#  'sau_này': <gensim.models.keyedvectors.Vocab at 0x7facd9e74c90>,
#  'seminar': <gensim.models.keyedvectors.Vocab at 0x7facd9e70550>,
#  'sinh_viên': <gensim.models.keyedvectors.Vocab at 0x7facd9e65950>,
#  'sinh_động': <gensim.models.keyedvectors.Vocab at 0x7facd9e81910>,
#  'slide': <gensim.models.keyedvectors.Vocab at 0x7facdc6b9450>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7facd9e84bd0>,
#  'sách': <gensim.models.keyedvectors.Vocab at 0x7facd9e84850>,
#  'sáng_tạo': <gensim.models.keyedvectors.Vocab at 0x7facd9e817d0>,
#  'sát': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c0d0>,
#  'sâu': <gensim.models.keyedvectors.Vocab at 0x7facd9e70590>,
#  'sôi_nổi': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c5d0>,
#  'sơ_sài': <gensim.models.keyedvectors.Vocab at 0x7facd9e88510>,
#  'sắp_xếp': <gensim.models.keyedvectors.Vocab at 0x7facd9e81110>,
#  'sẵn_sàng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84fd0>,
#  'sẽ': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e2d0>,
#  'số': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a890>,
#  'số_lượng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cb10>,
#  'sớm': <gensim.models.keyedvectors.Vocab at 0x7facd9e7aad0>,
#  'sử_dụng': <gensim.models.keyedvectors.Vocab at 0x7facd9e742d0>,
#  'sửa': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c550>,
#  'sự': <gensim.models.keyedvectors.Vocab at 0x7facd9e70e50>,
#  'tham_gia': <gensim.models.keyedvectors.Vocab at 0x7facd9e7acd0>,
#  'tham_khảo': <gensim.models.keyedvectors.Vocab at 0x7facd9e70d10>,
#  'thay': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ee50>,
#  'thay_vì': <gensim.models.keyedvectors.Vocab at 0x7facd9e6eb50>,
#  'thay_đổi': <gensim.models.keyedvectors.Vocab at 0x7facd9e70e90>,
#  'theo': <gensim.models.keyedvectors.Vocab at 0x7facd9e773d0>,
#  'theo_dõi': <gensim.models.keyedvectors.Vocab at 0x7facd9e81cd0>,
#  'thi': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ae90>,
#  'thiết_bị': <gensim.models.keyedvectors.Vocab at 0x7facd9e65bd0>,
#  'thiếu': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e6d0>,
#  'thoải_mái': <gensim.models.keyedvectors.Vocab at 0x7facd9e706d0>,
#  'thu_hút': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a710>,
#  'thuyết_trình': <gensim.models.keyedvectors.Vocab at 0x7facd9e81610>,
#  'thái_độ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a690>,
#  'thân_thiện': <gensim.models.keyedvectors.Vocab at 0x7facd9e77c90>,
#  'thêm': <gensim.models.keyedvectors.Vocab at 0x7facd9e705d0>,
#  'thì': <gensim.models.keyedvectors.Vocab at 0x7facd9e74290>,
#  'thích': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cbd0>,
#  'thôi': <gensim.models.keyedvectors.Vocab at 0x7facd9e74c10>,
#  'thông_báo': <gensim.models.keyedvectors.Vocab at 0x7facd9e777d0>,
#  'thông_tin': <gensim.models.keyedvectors.Vocab at 0x7facd9e65b10>,
#  'thú_vị': <gensim.models.keyedvectors.Vocab at 0x7facd9e81410>,
#  'thương': <gensim.models.keyedvectors.Vocab at 0x7facd9e84150>,
#  'thường': <gensim.models.keyedvectors.Vocab at 0x7facd9e74a90>,
#  'thường_xuyên': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e210>,
#  'thảo_luận': <gensim.models.keyedvectors.Vocab at 0x7facd9e88350>,
#  'thấy': <gensim.models.keyedvectors.Vocab at 0x7facd9e70290>,
#  'thầy': <gensim.models.keyedvectors.Vocab at 0x7facd9e65cd0>,
#  'thầy_giáo': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c890>,
#  'thật': <gensim.models.keyedvectors.Vocab at 0x7facd9e81a90>,
#  'thật_sự': <gensim.models.keyedvectors.Vocab at 0x7facd9e84e50>,
#  'thắc_mắc': <gensim.models.keyedvectors.Vocab at 0x7facd9e74150>,
#  'thế': <gensim.models.keyedvectors.Vocab at 0x7facd9e885d0>,
#  'thống_nhất': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c910>,
#  'thời_gian': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e050>,
#  'thời_lượng': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e490>,
#  'thứ': <gensim.models.keyedvectors.Vocab at 0x7facd9e74ad0>,
#  'thực_hiện': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c2d0>,
#  'thực_hành': <gensim.models.keyedvectors.Vocab at 0x7facd9e747d0>,
#  'thực_sự': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c710>,
#  'thực_tiễn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a650>,
#  'thực_tế': <gensim.models.keyedvectors.Vocab at 0x7facd9e70dd0>,
#  'tiếng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ce50>,
#  'tiếp_cận': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ac90>,
#  'tiếp_thu': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e590>,
#  'tiết': <gensim.models.keyedvectors.Vocab at 0x7facd9e70690>,
#  'toàn': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ce10>,
#  'trang': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c110>,
#  'trang_bị': <gensim.models.keyedvectors.Vocab at 0x7facd9e84b10>,
#  'trao_đổi': <gensim.models.keyedvectors.Vocab at 0x7facd9e70310>,
#  'trong': <gensim.models.keyedvectors.Vocab at 0x7facd9e702d0>,
#  'truyền_cảm_hứng': <gensim.models.keyedvectors.Vocab at 0x7facd9e818d0>,
#  'truyền_đạt': <gensim.models.keyedvectors.Vocab at 0x7facd9e74250>,
#  'trách_nhiệm': <gensim.models.keyedvectors.Vocab at 0x7facd9e88890>,
#  'tránh': <gensim.models.keyedvectors.Vocab at 0x7facd9e70b90>,
#  'trên': <gensim.models.keyedvectors.Vocab at 0x7facd9e65f10>,
#  'trình_bày': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ea90>,
#  'trình_độ': <gensim.models.keyedvectors.Vocab at 0x7facd9e88650>,
#  'trùng': <gensim.models.keyedvectors.Vocab at 0x7facd9e88810>,
#  'trước': <gensim.models.keyedvectors.Vocab at 0x7facd9e70f10>,
#  'trường': <gensim.models.keyedvectors.Vocab at 0x7facd9e772d0>,
#  'trường_hợp': <gensim.models.keyedvectors.Vocab at 0x7facd9e887d0>,
#  'trả_lời': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e110>,
#  'trễ': <gensim.models.keyedvectors.Vocab at 0x7facd9e77710>,
#  'trọng_tâm': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e710>,
#  'trực_quan': <gensim.models.keyedvectors.Vocab at 0x7facd9e846d0>,
#  'trực_tiếp': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c490>,
#  'tuy': <gensim.models.keyedvectors.Vocab at 0x7facd9e81e90>,
#  'tuy_nhiên': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cad0>,
#  'tuyệt_vời': <gensim.models.keyedvectors.Vocab at 0x7facd9e849d0>,
#  'tuần': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cf10>,
#  'tài_liệu': <gensim.models.keyedvectors.Vocab at 0x7facd9e708d0>,
#  'tâm': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c810>,
#  'tâm_huyết': <gensim.models.keyedvectors.Vocab at 0x7facd9e77dd0>,
#  'tâm_lý': <gensim.models.keyedvectors.Vocab at 0x7facd9e844d0>,
#  'tìm': <gensim.models.keyedvectors.Vocab at 0x7facd9e84cd0>,
#  'tìm_hiểu': <gensim.models.keyedvectors.Vocab at 0x7facd9e77f10>,
#  'tình_trạng': <gensim.models.keyedvectors.Vocab at 0x7facd9e77910>,
#  'tích_cực': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e0d0>,
#  'tính': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c210>,
#  'tôi': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a450>,
#  'tăng': <gensim.models.keyedvectors.Vocab at 0x7facd9e77610>,
#  'tăng_cường': <gensim.models.keyedvectors.Vocab at 0x7facd9e812d0>,
#  'tương_tác': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a5d0>,
#  'tại': <gensim.models.keyedvectors.Vocab at 0x7facd9e81a10>,
#  'tạo': <gensim.models.keyedvectors.Vocab at 0x7facd9e704d0>,
#  'tất_cả': <gensim.models.keyedvectors.Vocab at 0x7facd9e70210>,
#  'tận_tâm': <gensim.models.keyedvectors.Vocab at 0x7facd9e74810>,
#  'tận_tình': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ec10>,
#  'tận_tụy': <gensim.models.keyedvectors.Vocab at 0x7facd9e81710>,
#  'tập_trung': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a810>,
#  'tốn': <gensim.models.keyedvectors.Vocab at 0x7facd9e77810>,
#  'tốt': <gensim.models.keyedvectors.Vocab at 0x7facd9e74e50>,
#  'tổ_chức': <gensim.models.keyedvectors.Vocab at 0x7facd9e84190>,
#  'tới': <gensim.models.keyedvectors.Vocab at 0x7facd9e70750>,
#  'tụi': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a410>,
#  'từ': <gensim.models.keyedvectors.Vocab at 0x7facd9e77a50>,
#  'từng': <gensim.models.keyedvectors.Vocab at 0x7facd9e81450>,
#  'tự': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a590>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7facd9e70ed0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7facd9e81b10>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x7facd9e7af10>,
#  'viết': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c4d0>,
#  'việc': <gensim.models.keyedvectors.Vocab at 0x7facd9e65c90>,
#  'việt': <gensim.models.keyedvectors.Vocab at 0x7facd9e84950>,
#  'vui': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ca10>,
#  'vui_tính': <gensim.models.keyedvectors.Vocab at 0x7facd9e77110>,
#  'vui_vẻ': <gensim.models.keyedvectors.Vocab at 0x7facd9e70250>,
#  'và': <gensim.models.keyedvectors.Vocab at 0x7facd9e65b50>,
#  'vài': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c350>,
#  'vào': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ebd0>,
#  'vì': <gensim.models.keyedvectors.Vocab at 0x7facd9e74f50>,
#  'ví_dụ': <gensim.models.keyedvectors.Vocab at 0x7facd9e65e90>,
#  'văn': <gensim.models.keyedvectors.Vocab at 0x7facd9e84790>,
#  'vấn_đề': <gensim.models.keyedvectors.Vocab at 0x7facd9e70610>,
#  'vẫn': <gensim.models.keyedvectors.Vocab at 0x7facd9e74910>,
#  'vận_dụng': <gensim.models.keyedvectors.Vocab at 0x7facda14dc90>,
#  'vật_chất': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a150>,
#  'vậy': <gensim.models.keyedvectors.Vocab at 0x7facd9e84ed0>,
#  'về': <gensim.models.keyedvectors.Vocab at 0x7facd9e701d0>,
#  'với': <gensim.models.keyedvectors.Vocab at 0x7facdaaa7cd0>,
#  'vừa': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cc10>,
#  'vững': <gensim.models.keyedvectors.Vocab at 0x7facd9e841d0>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7facd9e88590>,
#  'xem': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ef90>,
#  'xin': <gensim.models.keyedvectors.Vocab at 0x7facd9e77050>,
#  'xong': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cfd0>,
#  'yêu_cầu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7c250>,
#  'yếu': <gensim.models.keyedvectors.Vocab at 0x7facd9e88150>,
#  'áp_dụng': <gensim.models.keyedvectors.Vocab at 0x7facd9e65a90>,
#  'áp_lực': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ed90>,
#  'ít': <gensim.models.keyedvectors.Vocab at 0x7facd9e70d50>,
#  'ôn': <gensim.models.keyedvectors.Vocab at 0x7facd9e84a50>,
#  'ôn_tập': <gensim.models.keyedvectors.Vocab at 0x7facd9e77390>,
#  'ý_kiến': <gensim.models.keyedvectors.Vocab at 0x7facd9e810d0>,
#  'đa_dạng': <gensim.models.keyedvectors.Vocab at 0x7facd9e70cd0>,
#  'đa_số': <gensim.models.keyedvectors.Vocab at 0x7facd9e7abd0>,
#  'đang': <gensim.models.keyedvectors.Vocab at 0x7facd9e6edd0>,
#  'đi': <gensim.models.keyedvectors.Vocab at 0x7facd9e65990>,
#  'đi_sâu': <gensim.models.keyedvectors.Vocab at 0x7facd9e74b90>,
#  'điều': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ad90>,
#  'điều_kiện': <gensim.models.keyedvectors.Vocab at 0x7facd9e81350>,
#  'điểm': <gensim.models.keyedvectors.Vocab at 0x7facd9e65a10>,
#  'điểm_danh': <gensim.models.keyedvectors.Vocab at 0x7facd9e84290>,
#  'đào_tạo': <gensim.models.keyedvectors.Vocab at 0x7facd9e84c10>,
#  'đánh_giá': <gensim.models.keyedvectors.Vocab at 0x7facd9e77b50>,
#  'đáp_án': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a310>,
#  'đáp_ứng': <gensim.models.keyedvectors.Vocab at 0x7facd9e77bd0>,
#  'đâu': <gensim.models.keyedvectors.Vocab at 0x7facd9e84050>,
#  'đây': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a350>,
#  'đã': <gensim.models.keyedvectors.Vocab at 0x7facd9e74d10>,
#  'đó': <gensim.models.keyedvectors.Vocab at 0x7facd9e77690>,
#  'đôi': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cd90>,
#  'đôi_khi': <gensim.models.keyedvectors.Vocab at 0x7facd9e81a50>,
#  'đúng': <gensim.models.keyedvectors.Vocab at 0x7facd9e6ec90>,
#  'đơn_giản': <gensim.models.keyedvectors.Vocab at 0x7facd9e84d90>,
#  'đưa': <gensim.models.keyedvectors.Vocab at 0x7facd9e74450>,
#  'được': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e8d0>,
#  'đạt': <gensim.models.keyedvectors.Vocab at 0x7facd9e88410>,
#  'đảm_bảo': <gensim.models.keyedvectors.Vocab at 0x7facd9e65fd0>,
#  'đầu': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a950>,
#  'đầu_tư': <gensim.models.keyedvectors.Vocab at 0x7facd9e84ad0>,
#  'đầy_đủ': <gensim.models.keyedvectors.Vocab at 0x7facd9ebddd0>,
#  'đặc_biệt': <gensim.models.keyedvectors.Vocab at 0x7facd9e74cd0>,
#  'đặt': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e250>,
#  'đến': <gensim.models.keyedvectors.Vocab at 0x7facd9e70810>,
#  'đề': <gensim.models.keyedvectors.Vocab at 0x7facd9e77c50>,
#  'đề_cương': <gensim.models.keyedvectors.Vocab at 0x7facd9e77c10>,
#  'đề_nghị': <gensim.models.keyedvectors.Vocab at 0x7facd9e70e10>,
#  'đề_tài': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ab50>,
#  'đều': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cf50>,
#  'để': <gensim.models.keyedvectors.Vocab at 0x7facd9e70050>,
#  'định_hướng': <gensim.models.keyedvectors.Vocab at 0x7facd9e84d10>,
#  'đọc': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a990>,
#  'đối_với': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a3d0>,
#  'đồ_án': <gensim.models.keyedvectors.Vocab at 0x7facd9e74550>,
#  'đồng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ca90>,
#  'động_lực': <gensim.models.keyedvectors.Vocab at 0x7facd9e7cc50>,
#  'đủ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7aed0>,
#  'đứng': <gensim.models.keyedvectors.Vocab at 0x7facd9e7a510>,
#  'ạ': <gensim.models.keyedvectors.Vocab at 0x7facd9e7ab10>,
#  'ảnh_hưởng': <gensim.models.keyedvectors.Vocab at 0x7facd9e776d0>,
#  'ở': <gensim.models.keyedvectors.Vocab at 0x7facd9e6e410>,
#  'ứng_dụng': <gensim.models.keyedvectors.Vocab at 0x7facd9e70d90>}

# %%
w2v_model.wv.most_similar(positive=["giảng_dạy", "đồ_án"], negative=["kiểm_tra"], topn=1)
# Out:
# [('đối_với', 0.39585497975349426)]

# %%
w2v_model.wv.save_word2vec_format('w2v_vsfc.txt', binary=False)

# %%
print(w2v_model['dạy'])
# Out:
# [-0.16160615 -0.08855243  0.06048952 -0.26187405 -0.16167095 -0.30898818
#   0.3246685   0.14753404  0.05460394  0.48221728  0.01714414 -0.03768282
#   0.14862181  0.32211828 -0.3155511  -0.13191213 -0.3149285  -0.09868582
#  -0.20129257  0.1632616  -0.20557818  0.06808359  0.22834508 -0.01325125
#  -0.17402202 -0.5377645   0.00652443  0.05708453  0.04776882 -0.08993167
#  -0.50745416  0.20603533  0.43503466 -0.35979775  0.14840536 -0.38188317
#   0.19013561 -0.19972058 -0.17524901 -0.4007956  -0.42311674  0.10964311
#   0.01922066  0.39602038  0.25856307  0.19007425 -0.16497019  0.6031791
#  -0.01105115  0.20601086  0.2915155   0.05493049  0.27975392 -0.09526739
#  -0.85252076 -0.34388736 -0.59686023  0.07490172  0.39078945 -0.17759736
#  -0.4644142  -0.05498283  0.08618779  0.25248143  0.5250795   0.27546734
#   0.41831028  0.0382987  -0.08985215  0.01436699  0.25648665  0.21720615
#  -0.18024462  0.13555603  0.11587378 -0.08814624  0.146718    0.2990964
#  -0.02543836  0.47849566 -0.37007913  0.2957891  -0.01974263  0.5459951
#   0.09262797 -0.14965339 -0.19450432 -0.272815   -0.31080866 -0.45802164
#   0.1547959  -0.2165319   0.30806324 -0.34981263  0.23939879 -0.26307145
#  -0.31503883  0.00428808  0.2814949   0.03854038 -0.66609925 -0.17523833
#  -0.1920268   0.57174385  0.36951664  0.2692038  -0.13026792  0.13803948
#   0.17428978 -0.17067403 -0.5348982   0.14592785  0.10837445 -0.57389194
#  -0.19019173 -0.04375742  0.81472456 -0.24926428  0.13940269  0.09485486
#  -0.43074533 -0.43688405 -0.16058305  0.16175883  0.24050699  0.35259366
#  -0.2766114   0.20793113 -0.21242335 -0.02870871  0.3419833  -0.15375258
#   0.41380867  0.26600882  0.5667274   0.20062958 -0.13039519  0.2017577
#   0.05329557 -0.1434035   0.36038202 -0.01624326  0.08446429  0.16640651
#  -0.428452    0.21123292 -0.23304226  0.41943538  0.12457065  0.02831384
#  -0.2904267  -0.19295718  0.13446985  0.4221827   0.28636107 -0.1476484
#  -0.64694285  0.2962643   0.37732753  0.0274756  -0.2415817  -0.03066406
#   0.53854173 -0.2383877   0.32588938 -0.13322847  0.2845687   0.27832147
#  -0.15438649 -0.11982678  0.0851064  -0.20076068 -0.04540639 -0.27705607
#   0.20095468  0.00834403 -0.24703887  0.56430995  0.2143755   0.6585947
#   0.26678315  0.71770316  0.59499115  0.42821538 -0.07312923  0.14278135
#  -0.51372105  0.12236635  0.5423314   0.5210602   0.0594029  -0.29374322
#   0.0366898  -0.14896195 -0.22411703 -0.46460003  0.56693566  0.1017022
#  -0.42914966 -0.72217023 -0.3093762   0.28039503 -0.42184657 -0.16359851
#   0.16137724  0.37802768 -0.30160645 -0.41562277 -0.24737822 -0.12231664
#  -0.31614062 -0.11782774  0.21931888 -0.03793447 -0.47470638  0.42596722
#   0.14946382  0.6335004  -0.1584341   0.5849519  -0.404863    0.0875608
#   0.05445777  0.05498452  0.05687719  0.23503686  0.14263715  0.26609835
#   0.09650914  0.09383217  0.01535521 -0.30946764  0.1092535   0.15735032
#   0.02762886 -0.24432787 -0.929841   -0.18174142 -0.04627795  0.23202762
#   0.18500377  0.14150538 -0.45673287 -0.29616985 -0.3652961   0.04832595
#  -0.08210427  0.13915816  0.39957958  0.05942081 -0.01861753  0.16869628
#  -0.21306558 -0.18087308  0.56214416  0.00778557  0.08140149  0.15482168
#  -0.33153018 -0.26508054  0.01566116 -0.01888787 -0.07723814  0.267287
#   0.10207934  0.24630855  0.23378283 -0.5304053   0.1938014  -0.1906703
#   0.5521488  -0.34730184  0.03612329 -0.7067696  -0.20493197 -0.28749585
#   0.02325541 -0.20538664 -0.30951333  0.03039073 -0.36558947 -0.17977437
#   0.23411353  0.2898136  -0.09348235 -0.32311392  0.1262996   0.03531671
#  -0.34823632 -0.17968877 -0.18014577  0.12412073  0.17160013  0.04849459
#  -0.0034353  -0.04837161 -0.03180536  0.06922122  0.07170361  0.43227962]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Word embeding

# %%
# make vocabulary 
from pyvi import ViTokenizer

V = []

for t in X_train:
    tokenized_sentence = ViTokenizer.tokenize(t)
    V = V + tokenized_sentence.split()

V = list(set(V))

# %%
len(V)
# Out:
# 3704

# %% [markdown]
# ## Cach 1: Tu build

# %%
# Building dictionary 
word_to_index = {w : (i+2) for i, w in enumerate(V)}

word_to_index['UNK'] = 1
word_to_index['PAD'] = 0

# Build index2w
index_to_word = {i: w for w, i in word_to_index.items()}

# %%
word_to_index
# Out:
# {'wzjwz323': 2,
#  'cách_thức': 3,
#  'nhập_tâm': 4,
#  'giữa_chừng': 5,
#  'nâng': 6,
#  'tham_gia': 7,
#  'gây_rối': 8,
#  'lồng_tiếng': 9,
#  'con': 10,
#  'chắc_chắn': 11,
#  'giảng_viên': 12,
#  'phone': 13,
#  'ở': 14,
#  'đối_phó': 15,
#  '2005': 16,
#  'vui': 17,
#  'wzjwz46': 18,
#  'trau_chuốt': 19,
#  'sướng': 20,
#  'gán': 21,
#  'speaking': 22,
#  'bản': 23,
#  'cuối': 24,
#  'kể': 25,
#  'wzjwz60': 26,
#  'học_hành': 27,
#  'tiêp': 28,
#  'dư': 29,
#  'chắc_hẳn': 30,
#  'tăng_cường_độ': 31,
#  'phí': 32,
#  'sôi_động': 33,
#  'rối': 34,
#  'tận': 35,
#  'lãnh_đạm': 36,
#  'tự_ý': 37,
#  'kế_tiếp': 38,
#  'việt': 39,
#  'nhanh': 40,
#  'đươc': 41,
#  'lau': 42,
#  'đói': 43,
#  'nhà_hàng': 44,
#  'rung': 45,
#  'cẩn_thận': 46,
#  'bấm': 47,
#  'gia_trưởng': 48,
#  'tương_thích': 49,
#  'cao_học': 50,
#  'vừa_ý': 51,
#  'mông_lung': 52,
#  'người_làm': 53,
#  'thu': 54,
#  'bẩn': 55,
#  'kho': 56,
#  'học_bổng': 57,
#  'lỳ': 58,
#  'tuổi': 59,
#  'vựa': 60,
#  'đa_số': 61,
#  'demo': 62,
#  'wzjwz156': 63,
#  'kiến_thức': 64,
#  'cân_bằng': 65,
#  '8': 66,
#  'học_sinh_viên': 67,
#  'chắp_vá': 68,
#  'hoang_mang': 69,
#  'wzjwz229': 70,
#  'trợ_giảng_dạy': 71,
#  'giao_thức': 72,
#  'bù': 73,
#  'động_lực_học': 74,
#  'thói_quen': 75,
#  'thúy': 76,
#  'thân_ái': 77,
#  'nhất_quán': 78,
#  'bỏ_qua': 79,
#  'wzjwz176': 80,
#  'hôi': 81,
#  '1h30': 82,
#  'it006dote12': 83,
#  'khiếu': 84,
#  'bất_bình_thường': 85,
#  'gái': 86,
#  'trễ': 87,
#  'wzjwz204': 88,
#  'cnpm': 89,
#  'bất_đạt': 90,
#  'rối_rắm': 91,
#  'tiếng_động_cơ': 92,
#  'robin': 93,
#  'nhận_thức': 94,
#  'treo': 95,
#  'thúc_giục': 96,
#  'dồi': 97,
#  'nặng': 98,
#  '4': 99,
#  'nhưng': 100,
#  'toàn': 101,
#  'dvd': 102,
#  'khắc_phục': 103,
#  'giời': 104,
#  'viết': 105,
#  'ép': 106,
#  'mà_lại': 107,
#  'chủ_nhật': 108,
#  'tiết': 109,
#  '3dsmax': 110,
#  'wzjwz36': 111,
#  'lao_công': 112,
#  'phân_công': 113,
#  'mức': 114,
#  'cấu_trúc': 115,
#  'wzjwz37': 116,
#  'dừng': 117,
#  'để_ý': 118,
#  'mai': 119,
#  'pl': 120,
#  'đò': 121,
#  'góp_phần': 122,
#  'hoạt': 123,
#  'luôn': 124,
#  'hạnh': 125,
#  'tổng_quan': 126,
#  'tình_hình': 127,
#  'thu_hút': 128,
#  'chiếu': 129,
#  'lâu': 130,
#  'tung': 131,
#  'quản_lý': 132,
#  'cảm_tính': 133,
#  'bực_mình': 134,
#  'jquery': 135,
#  'song_hành': 136,
#  'tầm_cỡ': 137,
#  'chuyển': 138,
#  'đáp_ứng': 139,
#  'over': 140,
#  '92': 141,
#  'thpt': 142,
#  'rẻ': 143,
#  'chửi': 144,
#  'trách_nhiệm': 145,
#  'bảo_mật': 146,
#  'tất_cả': 147,
#  'java': 148,
#  'đủ': 149,
#  'nhật': 150,
#  'đánh_giá': 151,
#  'giảm_thiểu': 152,
#  'thây': 153,
#  'xác_thực_tế': 154,
#  'xáo_trộn': 155,
#  'động_não': 156,
#  'kiểu': 157,
#  'sau_này': 158,
#  'turnitindotcom': 159,
#  'chiều': 160,
#  'outdoor': 161,
#  'ô_nhiễm': 162,
#  'chặn': 163,
#  'bụi': 164,
#  'in': 165,
#  'tích_cực': 166,
#  'có_hạn': 167,
#  'vô_cùng': 168,
#  'tính_tình': 169,
#  'đẩy': 170,
#  'hoàn_thiện': 171,
#  'đầu_tiên': 172,
#  'giải_pháp': 173,
#  '85': 174,
#  'dứt_khoát': 175,
#  'khóc': 176,
#  'phân_biệt': 177,
#  'vui_tươi': 178,
#  'chúng_ta': 179,
#  'not': 180,
#  'vào': 181,
#  'đề_cập': 182,
#  '7h20': 183,
#  'tuyển_dụng': 184,
#  'liên': 185,
#  'kiêm': 186,
#  'chốn': 187,
#  'anh_em': 188,
#  'kinh_doanh': 189,
#  'chữa': 190,
#  'bất': 191,
#  'lười': 192,
#  'nạp': 193,
#  'nhiêu': 194,
#  'wzjwz79': 195,
#  'thiếu': 196,
#  'làm_khó': 197,
#  'nản_chí': 198,
#  'bắt_bẻ': 199,
#  'đên': 200,
#  'tập_trung': 201,
#  'không_gian': 202,
#  'phúc_khảo': 203,
#  'sinh_nhật': 204,
#  'xung_quanh': 205,
#  'trực': 206,
#  'wzjwz86': 207,
#  'lãng_phí': 208,
#  'thưởng': 209,
#  'sẻ': 210,
#  'yêu_thương': 211,
#  'hâm_mộ': 212,
#  'is': 213,
#  'ic': 214,
#  'mình': 215,
#  'nhạt': 216,
#  'như_ý': 217,
#  'cởi_mở': 218,
#  'nâng_cấp_thiết_bị': 219,
#  'dựng_phim': 220,
#  'ngột_ngạt': 221,
#  'tránh': 222,
#  'thoả_đáng': 223,
#  'cùi': 224,
#  'wzjwz6': 225,
#  'phần': 226,
#  'tính_chất': 227,
#  'bayes': 228,
#  'trăm': 229,
#  'nhất_định': 230,
#  'sql': 231,
#  'xem_lại': 232,
#  'hữu_ích': 233,
#  'giúp_ích': 234,
#  'ư': 235,
#  'mượn': 236,
#  'thuyết_trình': 237,
#  'nhât': 238,
#  'chăm_chỉ': 239,
#  'viện': 240,
#  'đạng': 241,
#  'làm_nên': 242,
#  'chuông': 243,
#  'khiến': 244,
#  'nhồi_sọ': 245,
#  'kỷ_niệm': 246,
#  'tấn_công': 247,
#  'ngoài': 248,
#  'mơ_hồ': 249,
#  'chăng': 250,
#  'ubuntu': 251,
#  'mốt': 252,
#  'wzjwz117': 253,
#  'ý_kiến': 254,
#  'lượt': 255,
#  'lớp': 256,
#  'đi_đôi': 257,
#  'đơn': 258,
#  'mặt_khác': 259,
#  'wzjwz71': 260,
#  'linh_động': 261,
#  'điểm_danh': 262,
#  'tuyệt_đối': 263,
#  '2008': 264,
#  'hôm_nay': 265,
#  'đẹp': 266,
#  'sư_phạm': 267,
#  'hoặc': 268,
#  'kí_hiệu': 269,
#  'tập': 270,
#  'ngờ': 271,
#  'ăn': 272,
#  'đề': 273,
#  'bất_kỳ_công_nghệ_cụ_thể': 274,
#  'wzjwz83': 275,
#  'ngày': 276,
#  'di_động': 277,
#  'nhiêt': 278,
#  'nhẹ_nhàng': 279,
#  'bồi_bổ': 280,
#  'vắng': 281,
#  'òm': 282,
#  'wzjwz52': 283,
#  'kịp': 284,
#  'ổ_cắm': 285,
#  'truyển': 286,
#  'ngớ_ngẩn': 287,
#  'chủ': 288,
#  'phỏng': 289,
#  'hụt': 290,
#  'từng_lớp': 291,
#  'phương_hướng': 292,
#  '!': 293,
#  'chỉnh_sửa': 294,
#  'phong_trào': 295,
#  'bảo_đảm': 296,
#  'lê_thê': 297,
#  'egov': 298,
#  'tùy_họ': 299,
#  'love': 300,
#  'ontology': 301,
#  'unikey': 302,
#  'cam_chịu': 303,
#  'phát_hành': 304,
#  'như_vầy': 305,
#  'hòng': 306,
#  'đi_sát': 307,
#  'cứng': 308,
#  'cũ': 309,
#  'hiệu_suất': 310,
#  'cứ': 311,
#  'chân_thành': 312,
#  'nâng_cấp': 313,
#  'wzjwz299': 314,
#  '12': 315,
#  'ý_thức': 316,
#  'rắt': 317,
#  'cảm_tưởng': 318,
#  'truyên': 319,
#  'chú_trọng': 320,
#  'yêu_quý': 321,
#  'tưởng': 322,
#  'gần_gũi': 323,
#  'show': 324,
#  'rập_khuôn': 325,
#  'tươi': 326,
#  'network': 327,
#  'wzjwz119': 328,
#  'buôi': 329,
#  'chổ': 330,
#  'kéo_điểm': 331,
#  'đẩy_mạnh': 332,
#  'thiết_nghĩ': 333,
#  'wzjwz74': 334,
#  'nhận_diện': 335,
#  'gi': 336,
#  'phích': 337,
#  'mong_đợi': 338,
#  'xe': 339,
#  'wzjwz241': 340,
#  'đại_học': 341,
#  'tiết_kiệm': 342,
#  'kiện': 343,
#  'wed': 344,
#  'trên': 345,
#  'hơn': 346,
#  'gay_gắt': 347,
#  'gó': 348,
#  'trừ': 349,
#  'thày': 350,
#  '2048': 351,
#  '1': 352,
#  'wzjwz103': 353,
#  'gia_tăng': 354,
#  'dụng_cụ': 355,
#  'trầm_bổng': 356,
#  'nữ': 357,
#  'style': 358,
#  'nhắc_nhở': 359,
#  'im': 360,
#  'tín_chỉ': 361,
#  'giáo_trình': 362,
#  'rộng_rãi': 363,
#  '40': 364,
#  'mục_đích': 365,
#  'dân_lập': 366,
#  'học_tập_hợp_lý': 367,
#  'bắt_đầu': 368,
#  'mail': 369,
#  'danh': 370,
#  'dần': 371,
#  'rối_ren': 372,
#  'đại': 373,
#  'nhạt_nhẽo': 374,
#  'wzjwz162': 375,
#  'biên_soạn': 376,
#  'đau_đầu': 377,
#  'tóm_lại': 378,
#  'bus': 379,
#  'hay': 380,
#  'wzjwz3': 381,
#  'hề': 382,
#  'quy_định': 383,
#  'nho_nhỏ': 384,
#  'làm': 385,
#  'ví_dụ': 386,
#  '64': 387,
#  'mảng': 388,
#  'nhìn': 389,
#  'tìm_kiếm': 390,
#  'logic': 391,
#  'công_cụ': 392,
#  'thắc_mắc': 393,
#  'wzjwz127': 394,
#  'đắng': 395,
#  'thấm_thía': 396,
#  'kết_thúc': 397,
#  'nhặt': 398,
#  'hằng': 399,
#  '75': 400,
#  'chép': 401,
#  'sai_lầm': 402,
#  'listening': 403,
#  'kết_nối': 404,
#  'bạn_bè': 405,
#  'mỹ': 406,
#  'thiếu_cập': 407,
#  '-': 408,
#  'thống_kê': 409,
#  'cắt': 410,
#  'bóng_đá': 411,
#  'xứng_đáng': 412,
#  'để': 413,
#  'dày': 414,
#  'yêu_cầu_vượt': 415,
#  'hợp_ý': 416,
#  'sức': 417,
#  'chả': 418,
#  'tùm_lum': 419,
#  'thì': 420,
#  'quốc_phòng': 421,
#  'thể_hiện': 422,
#  'chữ': 423,
#  'trầm': 424,
#  'tổng_quát': 425,
#  'quăng': 426,
#  'chính_thức': 427,
#  'dậy': 428,
#  'kết': 429,
#  'truyền_cảm_hứng': 430,
#  'căn_chỉnh': 431,
#  'directx': 432,
#  'cuốn': 433,
#  'phân_hoá': 434,
#  'than_phiền': 435,
#  'biên_dịch': 436,
#  'nghỉ_ngơi': 437,
#  'wzjwz222': 438,
#  'lênin': 439,
#  'khả_quan': 440,
#  'sử_dụng': 441,
#  'bài_tập_kết_hợp_lý_thuyết': 442,
#  'kêu': 443,
#  'quốc_tế': 444,
#  'thi_thoảng': 445,
#  'pha_trò': 446,
#  'fork': 447,
#  'khôg': 448,
#  'kiệp': 449,
#  'tay': 450,
#  'uit': 451,
#  'wzjwz242': 452,
#  'mến': 453,
#  'chính': 454,
#  'đứt': 455,
#  'vấn': 456,
#  'hình_như': 457,
#  'chọn': 458,
#  'ipv6': 459,
#  'lạc_bộ': 460,
#  'vô_bổ': 461,
#  'điểm': 462,
#  'wzjwz224': 463,
#  'cổng': 464,
#  'vâng': 465,
#  'mặc_định': 466,
#  'thích_ứng': 467,
#  'assignments': 468,
#  'nháy': 469,
#  'hiệu_chỉnh': 470,
#  'ép_buộc': 471,
#  'trước': 472,
#  'một_tí': 473,
#  '11h55': 474,
#  'hóa_hợp': 475,
#  'internet': 476,
#  'đi_lại': 477,
#  'té': 478,
#  'với': 479,
#  'wwzjwz305': 480,
#  'wzjwz318': 481,
#  'xác_suất': 482,
#  'nằm': 483,
#  '10': 484,
#  'chìa': 485,
#  'năng': 486,
#  'suy_nghĩ': 487,
#  'code': 488,
#  'máy_nổ': 489,
#  'wzjwz61': 490,
#  'daadotuitdotedudotvn': 491,
#  'ứng_dụng_cụ_thể': 492,
#  'mạng': 493,
#  'tê': 494,
#  'khóa': 495,
#  'áo': 496,
#  'hóc_búa': 497,
#  '2015': 498,
#  'mẫu': 499,
#  'chu': 500,
#  'tý': 501,
#  'gấp_gáp': 502,
#  'ảnh_hưởng': 503,
#  'agile': 504,
#  'củng': 505,
#  'kiếm_hiệp': 506,
#  'khô_khan': 507,
#  'thực_tế_hóa': 508,
#  'cũng_nên': 509,
#  'miễn_sao': 510,
#  'wzjwz105': 511,
#  'chuột': 512,
#  'đăng': 513,
#  'yên_tĩnh': 514,
#  'đuổi': 515,
#  'wzjwz18': 516,
#  'thanh_tra': 517,
#  'đơn_giản_hóa': 518,
#  'wzjwz121': 519,
#  'có_thể': 520,
#  'hoàn_thành': 521,
#  'kết_nối_mạng': 522,
#  'quạt': 523,
#  'cần_thiết_kế': 524,
#  'kỹ': 525,
#  'giảng_giải': 526,
#  'nghèo_nàn': 527,
#  'giá_trị': 528,
#  'tủ': 529,
#  'phú': 530,
#  'wzjwz35': 531,
#  'abc': 532,
#  'nói_xấu': 533,
#  'đằng': 534,
#  'sửa': 535,
#  'cố_định': 536,
#  'lớn_tuổi': 537,
#  'đánh_bài': 538,
#  'wzjwz130': 539,
#  'wzjwz140': 540,
#  'vô_tư': 541,
#  'phục_vụ': 542,
#  'đảo_lộn': 543,
#  'rát': 544,
#  'tân': 545,
#  'ai': 546,
#  'vướng_mắc': 547,
#  'nhu_cầu_môn_học': 548,
#  'nào': 549,
#  'nổi': 550,
#  'wzjwz201': 551,
#  'bi': 552,
#  'xác_định': 553,
#  'ram': 554,
#  'chip': 555,
#  'thiên_vị': 556,
#  'tạt': 557,
#  'muốn': 558,
#  'mắng_chửi': 559,
#  'hỗn_loạn': 560,
#  'xen_lẫn': 561,
#  'la': 562,
#  'cuộc_đời': 563,
#  'đặp': 564,
#  'website': 565,
#  'như_thế': 566,
#  'thiên': 567,
#  'thậm_tệ': 568,
#  'giải_tán': 569,
#  'nóng_tính': 570,
#  'quy_tắc': 571,
#  'nhuần_nhuyễn': 572,
#  'tận_lực': 573,
#  'bây_giờ': 574,
#  'bài_tập_hợp_lý': 575,
#  'giao_lưu': 576,
#  'khuyết_điểm': 577,
#  'bảng_hiệu_quả': 578,
#  'wzjwz294': 579,
#  'add': 580,
#  'vô_lý': 581,
#  'kiên_quyết': 582,
#  'đầu_óc': 583,
#  'wzjwz166': 584,
#  'ngành': 585,
#  'quy_mô': 586,
#  'wzjwz285': 587,
#  'đế': 588,
#  'sở': 589,
#  'động': 590,
#  'wzjwz304': 591,
#  'chục': 592,
#  'step': 593,
#  'quyết_định': 594,
#  'ước': 595,
#  'lắc_đầu': 596,
#  'bổn_phận': 597,
#  'pha': 598,
#  'vui_nhộn': 599,
#  'đen': 600,
#  'chuyển_đổi': 601,
#  'vô_số': 602,
#  'mới_mẻ': 603,
#  'công_tác': 604,
#  'lâu_dài': 605,
#  'thơi': 606,
#  'it': 607,
#  'tính_năng': 608,
#  'giấc': 609,
#  'tiềm_ẩn': 610,
#  'đảm_nhận': 611,
#  'công_bố': 612,
#  'wzjwz307': 613,
#  'nổi_bật': 614,
#  'chém': 615,
#  'ko': 616,
#  'thư_viện': 617,
#  'truyện': 618,
#  'đợt': 619,
#  'não': 620,
#  'chút': 621,
#  'không_thể_hiện': 622,
#  'thí_nghiệm': 623,
#  'tả': 624,
#  'thực_hành_hình': 625,
#  'trường_học': 626,
#  'quên': 627,
#  'hẹn': 628,
#  'nền': 629,
#  'giơ': 630,
#  'xi_măng': 631,
#  'assembly': 632,
#  'xóa': 633,
#  'cứng_nhắc': 634,
#  'nghĩa': 635,
#  'chú_tâm': 636,
#  'lạc_đề': 637,
#  'wzjwz94': 638,
#  'chi': 639,
#  'gượng_ép': 640,
#  'ngữ_cảnh': 641,
#  'thỏa_đáng': 642,
#  'lớn_tiếng': 643,
#  'đầy_đủ': 644,
#  'matlab': 645,
#  'quãng': 646,
#  'độc': 647,
#  'nghi_ngờ': 648,
#  'nhà_trường': 649,
#  'bày': 650,
#  'ngồi': 651,
#  'ngay': 652,
#  'chàn': 653,
#  'thiết_kế': 654,
#  'công_tâm': 655,
#  'hầu_hết': 656,
#  'dẽ': 657,
#  'vật_chất': 658,
#  'sẵn_sàng': 659,
#  'ban': 660,
#  'hòa': 661,
#  'sưu_tầm': 662,
#  'laptop': 663,
#  'tóm': 664,
#  'fraction': 665,
#  'android': 666,
#  'kể_cả': 667,
#  'chuyện': 668,
#  'requirement': 669,
#  'kiễn': 670,
#  'hấp_dẫn': 671,
#  '%': 672,
#  'hài': 673,
#  'cao_độ': 674,
#  'thay_thế': 675,
#  'xin': 676,
#  'văn_hóa': 677,
#  'chịu_khó': 678,
#  'hiện_nay': 679,
#  'học_đòi_hỏi': 680,
#  'bề_ngoài': 681,
#  'trigger': 682,
#  'lỡ': 683,
#  'so_sánh': 684,
#  'giọng_điệu': 685,
#  '>': 686,
#  'dành': 687,
#  'biện': 688,
#  'máy_vi_tính': 689,
#  'smartphone': 690,
#  'tri_thức': 691,
#  'wzjwz158': 692,
#  'khuấy_động': 693,
#  'yếu_kém': 694,
#  'tầm': 695,
#  'sang': 696,
#  'thử_nghiệm': 697,
#  'điểu': 698,
#  'hiệu': 699,
#  'nhân_tạo': 700,
#  'một_vài': 701,
#  'trường': 702,
#  'giám': 703,
#  'cấm': 704,
#  'minh_họa': 705,
#  'trợ': 706,
#  'vote': 707,
#  'chảy': 708,
#  'quý_giá': 709,
#  'hệ_thống': 710,
#  'vòng_vòng': 711,
#  'seminar': 712,
#  'lý_thuyết_giảng_viên': 713,
#  'kịp_thời': 714,
#  'cải_cách': 715,
#  'bất_cứ': 716,
#  'cao_trào': 717,
#  'ngại': 718,
#  'ắt': 719,
#  'học_viên': 720,
#  'skype': 721,
#  'xin_lỗi': 722,
#  'lơ_là': 723,
#  'trải': 724,
#  'wzjwz182': 725,
#  'chịu': 726,
#  'trường_hợp': 727,
#  'gián_đoạn': 728,
#  'trao': 729,
#  'đĩnh_đạc': 730,
#  'bàn_luận': 731,
#  'linh_kiện': 732,
#  'liên_hệ': 733,
#  'vòng': 734,
#  'wzjwz11': 735,
#  'wzjwz264': 736,
#  'tra_tấn': 737,
#  'thi_viết': 738,
#  'wzjwz128': 739,
#  'chỉnh': 740,
#  'mở_mang': 741,
#  'hãy': 742,
#  'từ_vựng_học': 743,
#  'tai_nghe': 744,
#  'wzjwz12': 745,
#  'khía_cạnh': 746,
#  'tmf': 747,
#  'cắt_giảm': 748,
#  'hào_hứng': 749,
#  'luyện_tập': 750,
#  'hời_hợt': 751,
#  'đại_gia': 752,
#  'trực_tuyến': 753,
#  'nhau': 754,
#  'wzjwz315': 755,
#  'engine': 756,
#  'bầu': 757,
#  'đọc': 758,
#  'thi_đua': 759,
#  'ngày_càng': 760,
#  'lước': 761,
#  'vốn': 762,
#  'bề_mặt': 763,
#  'lap': 764,
#  'xinh': 765,
#  'tiên_tiến': 766,
#  'họ': 767,
#  "'": 768,
#  'một_lèo': 769,
#  'wtf': 770,
#  'dẫn_chứng': 771,
#  'vận': 772,
#  'miệt_mài': 773,
#  'đông_đủ': 774,
#  'hàng_đầu': 775,
#  'wzjwz1': 776,
#  'ý_muốn': 777,
#  'wzjwz133': 778,
#  'khác_biệt': 779,
#  'nữ_sinh_viên': 780,
#  'thầy_giáo': 781,
#  'cao_cấp': 782,
#  'nhìu': 783,
#  'mặc': 784,
#  'wzjwz252': 785,
#  'ngôn_từ': 786,
#  'aep': 787,
#  'vmware': 788,
#  'cấp': 789,
#  'kinh_tế': 790,
#  '245': 791,
#  'nỗ_lực': 792,
#  'tiểu_luận': 793,
#  'kính_trọng': 794,
#  'rải': 795,
#  'đam_mê': 796,
#  'share': 797,
#  'cài': 798,
#  'moodle': 799,
#  'đối_tượng': 800,
#  'biến': 801,
#  'sai_sót': 802,
#  'toàn_tập': 803,
#  'độc_đáo': 804,
#  'i': 805,
#  'vấn_đề_bài_học': 806,
#  'gom': 807,
#  'visual': 808,
#  'x': 809,
#  'thừa': 810,
#  'thời_hạn': 811,
#  'cô_đọng': 812,
#  'đa': 813,
#  'wzjwz209': 814,
#  'dữ': 815,
#  'đất': 816,
#  'ứng': 817,
#  'cao_trình_độ': 818,
#  'hiện_giờ': 819,
#  'hổi': 820,
#  'thành_viên': 821,
#  'mời': 822,
#  'phản_hồi': 823,
#  'soạn': 824,
#  'ỷ_lại': 825,
#  'phấn': 826,
#  'quy_ước': 827,
#  'giảng_giải_nhiệt_tình': 828,
#  'wzjwz199': 829,
#  'side': 830,
#  'người': 831,
#  'học_lực': 832,
#  'wzjwz274': 833,
#  'nói_chuyện': 834,
#  'giọng': 835,
#  'bài': 836,
#  'thật_sự': 837,
#  'thoại': 838,
#  'vài': 839,
#  'căng_thẳng': 840,
#  'cần': 841,
#  'may_mắn': 842,
#  'thành_phố': 843,
#  'cũ_kỹ': 844,
#  'down': 845,
#  'nhác': 846,
#  'nà': 847,
#  'bận_rộn': 848,
#  'lo': 849,
#  'wzjwz246': 850,
#  'tài_liệu': 851,
#  'sự_thật': 852,
#  'văn_bản': 853,
#  'wzjwz73': 854,
#  'kỳ_vọng': 855,
#  'tốt': 856,
#  'cầu': 857,
#  'nắm_bắt': 858,
#  's': 859,
#  'năm': 860,
#  'poster': 861,
#  'đắt': 862,
#  'hoàn_thành_công_việc': 863,
#  'hdl': 864,
#  'wzjwz291': 865,
#  'dựa': 866,
#  'làm_bằng': 867,
#  'wzjwz259': 868,
#  'video': 869,
#  'việc': 870,
#  'chuẩn_hóa': 871,
#  '2k3': 872,
#  'khích_lệ': 873,
#  'ví_dụng': 874,
#  'wzjwz174': 875,
#  'chuyên_tâm': 876,
#  'lười_biếng': 877,
#  'training': 878,
#  'xa_lạ': 879,
#  'nghe': 880,
#  'quản_trị': 881,
#  'tín_chỉ_thực_hành': 882,
#  'phát_biểu': 883,
#  'đợi': 884,
#  'kịp_thời_gian': 885,
#  'khoá_luận': 886,
#  'biện_pháp': 887,
#  'toán_học': 888,
#  'học_thuật': 889,
#  'wzjwz191': 890,
#  'wzjwz245': 891,
#  'phương_án': 892,
#  'phủ_nhận': 893,
#  'virus': 894,
#  'còn': 895,
#  'phù_hợp': 896,
#  'wzjwz164': 897,
#  'bớt': 898,
#  'mỉm': 899,
#  'hứng_khởi': 900,
#  'đụng': 901,
#  'nhồi_nhét': 902,
#  'hứng': 903,
#  'cực_khổ': 904,
#  'room': 905,
#  'biệt': 906,
#  'dự_án': 907,
#  'nhiếu': 908,
#  'servlet': 909,
#  'đặt': 910,
#  'pdf': 911,
#  'từ_ngữ': 912,
#  'một': 913,
#  'wzjwz226': 914,
#  'ngôn_ngữ': 915,
#  'viên': 916,
#  'đạt': 917,
#  'thuần_thục': 918,
#  'phối_hợp': 919,
#  'bậc': 920,
#  'nguyên_bản': 921,
#  'cho_cùng': 922,
#  'cho_qua': 923,
#  'wzjwz273': 924,
#  'wzjwz138': 925,
#  'y': 926,
#  'wzjwz324': 927,
#  'thích_hợp': 928,
#  'it003dote21': 929,
#  'xác_thực': 930,
#  'công_nghệ': 931,
#  'cần_mẫn': 932,
#  'tình': 933,
#  'nhắc': 934,
#  'trình': 935,
#  'đặc_điểm': 936,
#  'giới_thiệu': 937,
#  'giao_diện': 938,
#  'bối_rối': 939,
#  'lưu_loát': 940,
#  'bổ_trợ': 941,
#  'một_số_thành_phần': 942,
#  'tầm_vóc': 943,
#  'sâu_sắc': 944,
#  '13h30': 945,
#  'đóng_góp_ý_kiến': 946,
#  'tín_hiệu_số': 947,
#  'wzjwz55': 948,
#  'poison': 949,
#  'động_lực': 950,
#  '13': 951,
#  'khí_chất': 952,
#  'thường': 953,
#  'vững_chắc': 954,
#  'cho': 955,
#  'đài': 956,
#  'bao_phủ': 957,
#  'ngợp': 958,
#  'trực_quan': 959,
#  'wzjwz208': 960,
#  'kéo': 961,
#  'ngoảnh': 962,
#  'hứng_thú': 963,
#  'ios': 964,
#  'khoảng_cách': 965,
#  'thiêng': 966,
#  'muôn': 967,
#  'gió': 968,
#  'kéo_dài': 969,
#  'chỉ_dẫn': 970,
#  'biệt_tích': 971,
#  'ca': 972,
#  'chấp_nhận': 973,
#  'chào': 974,
#  'version': 975,
#  'máy_tính': 976,
#  'quick': 977,
#  'nhờ': 978,
#  'while': 979,
#  'thấm': 980,
#  'wzjwz21': 981,
#  'famous': 982,
#  'trở_đi': 983,
#  'ebook': 984,
#  'ngược_lại': 985,
#  'đỡ': 986,
#  'phong_thái': 987,
#  'thực_hiện_tại': 988,
#  'điện_thoại': 989,
#  'wzjwz25': 990,
#  '13h45': 991,
#  'quá_sức': 992,
#  'cải_tiến': 993,
#  'trang': 994,
#  'do': 995,
#  'cảm_tình': 996,
#  'lẽ': 997,
#  'nhất_là': 998,
#  'word': 999,
#  'béo': 1000,
#  'phỏng_vấn': 1001,
#  ...}

# %%
X_train.values
# Out:
# array(['slide giáo trình đầy đủ .',
#        'nhiệt tình giảng dạy , gần gũi với sinh viên .',
#        'đi học đầy đủ full điểm chuyên cần .', ...,
#        'giao bài tập quá nhiều .', 'giáo viên dạy dễ hiểu , nhiệt tình .',
#        'gói gọn doubledot hay , tận tình , phù hợp với mọi trình độ cũng như nhu cầu môn học .'],
#       dtype=object)

# %%
from pyvi import ViTokenizer

ViTokenizer.tokenize("slide giáo trình đầy đủ ")
# Out:
# 'slide giáo_trình đầy_đủ'

# %%
t = "slide giáo_trình đầy_đủ"
t.split()
# Out:
# ['slide', 'giáo_trình', 'đầy_đủ']

# %%
word_to_index['đầy_đủ']
# Out:
# 644

# %%
t_encode = [1996, 1097,  3242, 0, 0 ,0, 0 ]

# %%
word_to_index["PAD"]
# Out:
# 0

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from pyvi import ViTokenizer

max_len = 100

def encoding(X):
    sentences = []
    
    for t in X:
        # tach tu 
        tokenized_sentence = ViTokenizer.tokenize(t)
        sentences.append(tokenized_sentence)
    
    X = []
    for s in sentences:
        sent = []
        for w in s.split():
            try:
                sent.append(word_to_index[w])
            except:
                sent.append(word_to_index["UNK"])
        X.append(sent)
    
    # Padding du lieu theo do dai cau (maxlen)
    X = pad_sequences(maxlen = max_len, sequences = X, padding = "post", value = word_to_index["PAD"])

    return X

# %% [markdown]
# ## Cach 2: dung ham co san trong Keras

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from pyvi import ViTokenizer
from keras.preprocessing.text import Tokenizer

max_len = 100


word_tokenizer = Tokenizer(oov_token=-1)
word_tokenizer.fit_on_texts(X_train)

word_2_index = word_tokenizer.word_index
word_2_index['pad'] = 0
word_2_index['unk'] = -1


index_to_word = {i: w for w, i in word_to_index.items()}

def encoding(X):
    sentences = []
    
    for t in X:
        tokenized_sentence = ViTokenizer.tokenize(t)
        sentences.append(tokenized_sentence)
    
    X = word_tokenizer.texts_to_sequences(sentences)
    X = pad_sequences(maxlen = max_len, sequences = X, padding = "post", value = word_2_index['pad'])

    return X

# %% [markdown]
# ## Build model

# %%
X_train_encoded = encoding(X_train)
X_dev_encoded = encoding(X_dev)
X_test_encoded = encoding(X_test)

# %%
X_train_encoded
# Out:
# array([[ 120,   46,   52, ...,    0,    0,    0],
#        [  14,    9,    3, ...,    0,    0,    0],
#        [ 100,    7,  123, ...,    0,    0,    0],
#        ...,
#        [ 333,    8,   18, ...,    0,    0,    0],
#        [  46,    2,    4, ...,    0,    0,    0],
#        [1295,  505,  293, ...,    0,    0,    0]], dtype=int32)

# %%
from keras.layers import Dense, Embedding, Flatten
from keras.models import Model, Input
from keras.initializers import Constant

num_words = len(word_2_index)
input = Input(shape = (max_len, ))
emb = Embedding(input_dim=num_words+1,
                    output_dim=300,
                    input_length=max_len)(input)
flat = Flatten()(emb)
output = Dense(3, activation="sigmoid")(flat)

model = Model(input, output)
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['binary_accuracy'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 100, 300)          747600
# _________________________________________________________________
# flatten (Flatten)            (None, 30000)             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 90003
# =================================================================
# Total params: 837,603
# Trainable params: 837,603
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import to_categorical

model.fit(X_train_encoded, to_categorical(y_train, num_classes=3), 
          validation_data=(X_dev_encoded, to_categorical(y_dev, num_classes=3)), 
          batch_size=128, epochs=10)
# Out:
# Epoch 1/10
# 90/90 [==============================] - 4s 35ms/step - loss: 0.3690 - binary_accuracy: 0.8397 - val_loss: 0.2374 - val_binary_accuracy: 0.9177
# Epoch 2/10
# 90/90 [==============================] - 3s 33ms/step - loss: 0.1927 - binary_accuracy: 0.9338 - val_loss: 0.1952 - val_binary_accuracy: 0.9292
# Epoch 3/10
# 90/90 [==============================] - 3s 33ms/step - loss: 0.1560 - binary_accuracy: 0.9467 - val_loss: 0.1767 - val_binary_accuracy: 0.9360
# Epoch 4/10
# 90/90 [==============================] - 3s 33ms/step - loss: 0.1334 - binary_accuracy: 0.9561 - val_loss: 0.1738 - val_binary_accuracy: 0.9394
# Epoch 5/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.1171 - binary_accuracy: 0.9613 - val_loss: 0.1786 - val_binary_accuracy: 0.9349
# Epoch 6/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.1010 - binary_accuracy: 0.9675 - val_loss: 0.1759 - val_binary_accuracy: 0.9402
# Epoch 7/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.0877 - binary_accuracy: 0.9730 - val_loss: 0.1795 - val_binary_accuracy: 0.9391
# Epoch 8/10
# 90/90 [==============================] - 3s 33ms/step - loss: 0.0764 - binary_accuracy: 0.9772 - val_loss: 0.1861 - val_binary_accuracy: 0.9358
# Epoch 9/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.0664 - binary_accuracy: 0.9809 - val_loss: 0.1903 - val_binary_accuracy: 0.9377
# Epoch 10/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.0584 - binary_accuracy: 0.9841 - val_loss: 0.2006 - val_binary_accuracy: 0.9328

# %%
import numpy as np
y_pred_test = model.predict(X_test_encoded)
y_pred_test = np.argmax(y_pred_test, axis=-1)

# %%
from sklearn.metrics import f1_score

print(f1_score(y_test, y_pred_test, average='micro')*100)
# Out:
# 89.13455464308277

# %% [markdown]
# # Pre-trained Embedding

# %%
pip install pyvi
# Out:
# Requirement already satisfied: pyvi in /usr/local/lib/python3.7/dist-packages (0.1.1)
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.7/dist-packages (from pyvi) (0.3.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.62.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.9.7)

# %%
# Read embedding
word_dict = []
embeddings_index = {}
embedding_dim = 300
max_feature = len(embeddings_index) + 2

f = open(path + '/W2V_ner.vec')
for line in f:
    values = line.split(' ')
    word = values[0] 
    word_dict.append(word)
    try:
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    except Exception as e:
        pass
f.close()

print('Embedding data loaded')
# Out:
# Embedding data loaded

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from pyvi import ViTokenizer
from keras.preprocessing.text import Tokenizer

max_len = 100

word_tokenizer = Tokenizer(oov_token=-1)
word_tokenizer.fit_on_texts(X_train.values)
word_to_index = word_tokenizer.word_index
word_to_index['pad'] = 0
word_to_index['unk'] = -1

index_to_word = {i: w for w, i in word_to_index.items()}

def encoding(X):
    sentences = []
    
    for t in X:
        tokenized_sentence = ViTokenizer.tokenize(t)
        sentences.append(tokenized_sentence)
    
    X = word_tokenizer.texts_to_sequences(sentences)
    X = pad_sequences(maxlen = max_len, sequences = X, padding = "post", value = word_to_index['pad'])

    return X

# %%
# first create a matrix of zeros, this is our embedding matrix
embedding_matrix = np.zeros((num_words, embedding_dim))

# for each word in out tokenizer lets try to find that work in our w2v model
for word, i in word_to_index.items():
    if i > max_feature:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
    else:
        # doesn't exist, assign a random vector
        embedding_matrix[i] = np.random.randn(embedding_dim)

# %%
X_train_encoded = encoding(X_train)
X_dev_encoded = encoding(X_dev)
X_test_encoded = encoding(X_test)

# %%
from keras.layers import Dense, Embedding, Flatten
from keras.models import Model, Input
from keras.initializers import Constant

num_words = len(word_to_index)

input = Input(shape = (max_len, ))
emb = Embedding(input_dim=num_words,
                    output_dim=embedding_dim,
                    embeddings_initializer=Constant(embedding_matrix),
                    input_length=max_len,
                    trainable=True)(input)
flat = Flatten()(emb)
output = Dense(3, activation="sigmoid")(flat)

model = Model(input, output)
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['binary_accuracy'])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 100, 300)          747300
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30000)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 90003
# =================================================================
# Total params: 837,303
# Trainable params: 837,303
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import to_categorical

model.fit(X_train_encoded, to_categorical(y_train, num_classes=3), 
          validation_data=(X_dev_encoded, to_categorical(y_dev, num_classes=3)), batch_size=128, epochs=10)
# Out:
# Epoch 1/10
# 90/90 [==============================] - 3s 34ms/step - loss: 1.0061 - binary_accuracy: 0.7481 - val_loss: 0.4472 - val_binary_accuracy: 0.7875
# Epoch 2/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2744 - binary_accuracy: 0.8991 - val_loss: 0.2249 - val_binary_accuracy: 0.9177
# Epoch 3/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2013 - binary_accuracy: 0.9325 - val_loss: 0.2043 - val_binary_accuracy: 0.9314
# Epoch 4/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.1959 - binary_accuracy: 0.9348 - val_loss: 0.1847 - val_binary_accuracy: 0.9339
# Epoch 5/10
# 90/90 [==============================] - 3s 33ms/step - loss: 0.1864 - binary_accuracy: 0.9372 - val_loss: 0.1981 - val_binary_accuracy: 0.9364
# Epoch 6/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.2673 - binary_accuracy: 0.9447 - val_loss: 0.3161 - val_binary_accuracy: 0.9328
# Epoch 7/10
# 90/90 [==============================] - 3s 33ms/step - loss: 0.1486 - binary_accuracy: 0.9528 - val_loss: 0.2542 - val_binary_accuracy: 0.9200
# Epoch 8/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.1239 - binary_accuracy: 0.9589 - val_loss: 0.2163 - val_binary_accuracy: 0.9343
# Epoch 9/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.1255 - binary_accuracy: 0.9585 - val_loss: 0.2162 - val_binary_accuracy: 0.9362
# Epoch 10/10
# 90/90 [==============================] - 3s 32ms/step - loss: 0.1123 - binary_accuracy: 0.9632 - val_loss: 0.2205 - val_binary_accuracy: 0.9280

# %%
import numpy as np
y_pred_test = model.predict(X_test_encoded)
y_pred_test = np.argmax(y_pred_test, axis=-1)

# %%
from sklearn.metrics import f1_score

print(f1_score(y_test, y_pred_test, average='macro')*100)
# Out:
# 73.76726818588334
